# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_groq import ChatGroq
llm = ChatGroq(
    model="llama-3.3-70b-versatile"
)

# %%
from pydantic import BaseModel, Field

# %%
class ResponseStructure(BaseModel):
    name:str = Field(description="Complete Name")
    age:int = Field(description="Age")
structured_llm = llm.with_structured_output(ResponseStructure)
res = structured_llm.invoke("Hey I'm Pranav And i'm 22 years old")
print(res.name)
print(res.age)
# Out:
# Pranav
# 22

# %%
from typing import List
class Movies(BaseModel):
    title:str = Field(description="Movie Title")
    year:int = Field(description="Movie Released Year.")


class AllMoviews(BaseModel):
    movies:List[Movies]

movie_llm = llm.with_structured_output(AllMoviews)

# %%
res = movie_llm.invoke("Give me three Sci-Fi movie")
res.movies
# Out:
# [Movies(title='Inception', year=2010),
#  Movies(title='Interstellar', year=2014),
#  Movies(title='Blade Runner 2049', year=2017)]
