# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
llm = ChatGoogleGenerativeAI(
    model = "gemini-3.1-flash-lite"
)

# %%
res = llm.invoke("Hey tell me a joke about valo, im G1 rank ")
res.text
# Out:
# 'Since you’re Gold 1, you’re officially in the "I have mechanical aim but zero game sense" stage. Here’s one for you:\n\n**Why did the Gold 1 player cross the road?**\n\nBecause their team told them to "rotate," so they dry-peeked into mid, got one-tapped by a Sheriff, and now they’re typing "gg team diff" in all chat while their Sage still has their ult.'
