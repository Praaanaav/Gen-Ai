# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
llm = ChatGoogleGenerativeAI(
    model = "gemini-3.1-flash-lite"
)

# %%
res = llm.invoke("PM of India ")
res.text
# Out:
# 'The current Prime Minister of India is **Narendra Modi**. He has been serving in this position since May 2014.'
