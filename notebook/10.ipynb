# %%
from langchain_ollama import ChatOllama
from langchain_core.prompts import ChatPromptTemplate
llm = ChatOllama(
    model=""
)

prompt = ChatPromptTemplate.from_messages(
    ("system","Translate to {language}"),
    ("user","{query}")
)
chains = prompt | llm 
res = chains.invoke({"language":"Hinglish", "query":"I love LangChain"})
res
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 7
#       3 llm = ChatOllama(
#       4     model=""
#       5 )
#       6
# ----> 7 prompt = ChatPromptTemplate.from_messages(
#       8     ("system","Translate to {language}"),
#       9     ("user","{query}")
#      10 )
#
# File d:\Gen Ai Placement\env\Lib\site-packages\langchain_core\prompts\chat.py:1172, in ChatPromptTemplate.from_messages(cls, messages, template_format)
#    1123 @classmethod
#    1124 def from_messages(
#    1125     cls,
#    1126     messages: Sequence[MessageLikeRepresentation],
#    1127     template_format: PromptTemplateFormat = "f-string",
#    1128 ) -> ChatPromptTemplate:
#    1129     """Create a chat prompt template from a variety of message formats.
#    1130
#    1131     Examples:
#    (...)   1170
#    1171     """
# -> 1172     return cls(messages, template_format=template_format)
#
# File d:\Gen Ai Placement\env\Lib\site-packages\langchain_core\prompts\chat.py:977, in ChatPromptTemplate.__init__(self, messages, template_format, **kwargs)
#     907 def __init__(
#     908     self,
#     909     messages: Sequence[MessageLikeRepresentation],
#    (...)    912     **kwargs: Any,
#     913 ) -> None:
#     914     """Create a chat prompt template from a variety of message formats.
#     915
#     916     Args:
#    (...)    974         ```
#     975     """
#     976     messages_ = [
# --> 977         _convert_to_message_template(message, template_format)
#     978         for message in messages
#     979     ]
#     981     # Automatically infer input variables from messages
#     982     input_vars: set[str] = set()
#
# File d:\Gen Ai Placement\env\Lib\site-packages\langchain_core\prompts\chat.py:1450, in _convert_to_message_template(message, template_format)
#    1448     message_ = message
#    1449 elif isinstance(message, str):
# -> 1450     message_ = _create_template_from_message_type(
#    1451         "human", message, template_format=template_format
#    1452     )
#    1453 elif isinstance(message, (tuple, dict)):
#    1454     if isinstance(message, dict):
#
# File d:\Gen Ai Placement\env\Lib\site-packages\langchain_core\prompts\chat.py:1360, in _create_template_from_message_type(message_type, template, template_format)
#    1346 """Create a message prompt template from a message type and template string.
#    1347
#    1348 Args:
#    (...)   1357     ValueError: If unexpected message type.
#    1358 """
#    1359 if message_type in {"human", "user"}:
# -> 1360     message: BaseMessagePromptTemplate = HumanMessagePromptTemplate.from_template(
#    1361         cast("str", template), template_format=template_format
#    1362     )
#    1363 elif message_type in {"ai", "assistant"}:
#    1364     message = AIMessagePromptTemplate.from_template(
#    1365         cast("str", template), template_format=template_format
#    1366     )
#
# File d:\Gen Ai Placement\env\Lib\site-packages\langchain_core\prompts\chat.py:442, in _StringImageMessagePromptTemplate.from_template(cls, template, template_format, partial_variables, **kwargs)
#     437 prompt: (
#     438     StringPromptTemplate
#     439     | list[StringPromptTemplate | ImagePromptTemplate | DictPromptTemplate]
#     440 )
#     441 if isinstance(template, str):
# --> 442     prompt = PromptTemplate.from_template(
#     443         template,
#     444         template_format=template_format,
#     445         partial_variables=partial_variables,
#     446     )
#     447     return cls(prompt=prompt, **kwargs)
#     448 if isinstance(template, Sequence):
#
# File d:\Gen Ai Placement\env\Lib\site-packages\langchain_core\prompts\prompt.py:298, in PromptTemplate.from_template(cls, template, template_format, partial_variables, **kwargs)
#     256 @classmethod
#     257 def from_template(
#     258     cls,
#    (...)    263     **kwargs: Any,
#     264 ) -> PromptTemplate:
#     265     """Load a prompt template from a template.
#     266
#     267     !!! warning "Security"
#    (...)    296         The prompt template loaded from the template.
#     297     """
# --> 298     input_variables = get_template_variables(template, template_format)
#     299     partial_variables_ = partial_variables or {}
#     301     if partial_variables_:
#
# File d:\Gen Ai Placement\env\Lib\site-packages\langchain_core\prompts\string.py:323, in get_template_variables(template, template_format)
#     321 else:
#     322     msg = f"Unsupported template format: {template_format}"
# --> 323     raise ValueError(msg)
#     325 return sorted(input_variables)
#
# ValueError: Unsupported template format: ('user', '{query}')
