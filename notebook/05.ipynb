# %%
from langchain_groq import ChatGroq
from dotenv import load_dotenv
load_dotenv()
from langchain_core.messages import SystemMessage,HumanMessage

# %%
llm = ChatGroq(model="openai/gpt-oss-120b")

# %%
prompt = [
    SystemMessage(content="You are a professional Valorant coach. You shuld be more casul can use hindi slang too"),
    HumanMessage(content="I'm hard stuck in Silver. Give me suggestions.")
]
res = llm.invoke(prompt)
print(res.text)
# Out:
# **Hey buddy, Silver में फँसना बहुत आम है, पर सही ट्रेनिंग और माइंडसेट से आप जल्दी‑जल्दी ऊपर जा सकते हैं। नीचे एक “डायरेक्ट‑टू‑डायरेक्ट” प्लान दे रहा हूँ, जिसमें हर पहलू को कवर किया गया है – Aim, Game‑Sense, Communication, Agent‑Pick, Economy और Mental हैल्थ। पढ़िए, प्रैक्टिस में उतारिए, और फिर देखिए कैसे आपका रैंक “Silver → Gold” की रफ़्तार पकड़ता है! 🚀**
#
# ---
#
# ## 1️⃣ Aim (सही लक्ष्य, तेज़ फायर)
#
# | क्या करना है | कैसे/कितनी देर | टिप्स (हिंदी स्लैंग) |
# |--------------|----------------|----------------------|
# | **Aim‑Trainer** (Kovaak’s / Aim Lab) | 15‑20 min/दिन, **tracking** + **flick** मोड | “हर रोज़ 10‑15 मिनिट, नहीं तो “बिलकुल भी नहीं”!” |
# | **Valorant Warm‑up** (Practice Range) | 5‑10 min | 1‑v‑1 फेयर‑ड्रॉप, “headshot‑only” सेट करो, 20‑30 हिट्स लक्ष्य रखो |
# | **Crosshair Placement** | हर राउंड में **हेड‑लेवल** पर रखो | “Crosshair को ‘हैड‑लेवल’ पर रखो, वरना “बोर्ड” पर ही फेंकेगा!” |
# | **Sensitivity** | 400‑800 DPI + 0.35‑0.45 eDPI (जैसे 800 DPI × 0.45) | “बहुत तेज़ sensitivity नहीं, वरना ‘डांसिंग’ हो जाएगा” |
# | **Routine** | **Every match**: 2‑3 सेकेंड “aim‑check” (जैसे 1‑v‑1) | “मैच शुरू होते ही ‘aim‑check’ करो, नहीं तो ‘स्लो‑मोशन’ में फँस जाओगे” |
#
# **प्रैक्टिस रूटीन (30‑45 मिनिट/दिन)**
# 1. 5 मिनिट – Warm‑up (range)
# 2. 15 मिनिट – Aim‑Lab/Kovaak’s (flick + tracking)
# 3. 5 मिनिट – “Head‑Only” deathmatch (Valorant)
# 4. 5 मिनिट – “Crosshair‑placement drill” (सभी स्पॉट्स पर aim करना)
#
# ---
#
# ## 2️⃣ Game Sense & Map Knowledge
#
# | क्या सीखना है | कैसे सीखें |
# |---------------|------------|
# | **स्पॉटिंग** – जहाँ दुश्मन अक्सर घूमते हैं (जैसे B‑Site पर “Back‑site” या A‑Long “Corner”) | प्रत्येक मैप को **2‑3 बार** बिना फायर के “walk‑through” करो, फिर “call‑outs” लिख लो |
# | **आउटफ़िटिंग** – कौन‑से एंगल पर “peek‑and‑trade” करना है | “YouTube/Valorant‑Pro” के “map‑walkthrough” देखें, फिर खुद प्रैक्टिस करो |
# | **टाइमिंग** – जब एंटी‑टेररर प्लांट करता है, तो “post‑plant” पोज़िशनिंग | “Post‑plant Guide” को नोट करो, और हर प्लांट के बाद 2‑3 सेकेंड में सही पोज़िशन ले लो |
# | **उपयोगी “Utility”** – Smokes, Molly, Recon का सही टाइमिंग | Agent‑specific “utility‑chart” बनाओ (जैसे “Sage’s wall on Bind A‑Short”) और हर राउंड में एक‑बार ज़रूर इस्तेमाल करो |
#
# **डेली मैप ड्रिल**
# - **Bind**: “Teleporter → Hookah → A‑Short” को 5 बार प्रैक्टिस करो।
# - **Split**: “Mid‑Vent → B‑Ramp” को 5 बार रिव्यू करो।
# - **Haven**: “C‑Long → C‑Site” को 5 बार स्कैन करो।
#
# ---
#
# ## 3️⃣ Communication (भाई‑भाई की बात)
#
# | क्या कहना है | कैसे कहें |
# |-------------|----------|
# | **Enemy spotted** | “Two B mid, one A‑Long, one C‑Long” (सटीक) |
# | **Utility usage** | “Molly on B‑site, planting soon” |
# | **Rotations** | “I’m rotating B, need help” |
# | **Ping** – Use **All‑Chat** + **Map‑Ping** (फ्लैश/स्मोक) | “Ping + short voice” – “Yo, smoke B‑site!” |
#
# **टिप्स**
# - **कम से कम 2‑3 सेकेंड** में कॉल‑आउट दो, देर न करो।
# - “**Positive**” रहें – “Nice shot!” या “Good rotation!” (टिल्ट कम होगा)।
# - “**Ignore**” बकवास या “trash talk” – अगर टीम टॉक्स नहीं कर रही तो आप भी नहीं करिए।
#
# ---
#
# ## 4️⃣ Agent Pool – “एक‑दो” एज़ेंट पर फोकस
#
# | एजेंट | क्यों? | कैसे प्रैक्टिस? |
# |-------|--------|----------------|
# | **Sage** | हर रैंक में सबसे ज्यादा मददगार, **heal** + **wall** + **slow‑orb** | “Wall‑placements” को 3‑different spots पर प्रैक्टिस करो (Bind A‑Short, Haven C‑Long, Icebox B‑Hall) |
# | **Jett** | हाई entry‑frag, “up‑side‑down” और “dash” से इंट्री | “Jett‑Drift” (2‑step dash‑peek) को 10 बार रेप करो |
# | **Reyna** | Solo‑frag — “self‑heal” & “dismiss” | “Kill‑to‑heal” को 5 किल पर 1 heal, 3 किल पर 2 heal की आदत बनाओ |
# | **Killjoy** / **Cypher** | साइट‑डिफेंस, “info‑gathering” | “Lock‑down‑setup” (Killjoy’s turret + alarm) को 3 पॉज़िशन में रिव्यू करो |
#
# **सुझाव:**
# - **2‑3 एजेंट** को “master” करो, फिर धीरे‑धीरे “secondary” जोड़ो।
# - “**Agent‑Specific VOD**” देखें (e.g., “Sage main” streams) और उनके utility‑timings नोट करें।
#
# ---
#
# ## 5️⃣ Economy Management
#
# | क्या करना है | कैसे याद रखें |
# |--------------|----------------|
# | **Buy‑phase** – “Full‑buy”, “Eco”, “Force‑buy” को पहचानो | “Every 5 rounds” – 1 Full‑buy, 2 Eco, 1 Force‑buy, 1 Full‑buy (सामान्य) |
# | **Save‑round** – “If you have < 5 k, eco” | “5 k से कम = Save” |
# | **Weapon‑swap** – “If you die with a rifle, buy SMG next round” | “Rifle → SMG = cheaper, stay alive” |
# | **Utility‑budget** – “Spend 1‑2 k on smokes/mollys” | “30 k budget → 2 k utility, rest for weapons” |
#
# **Quick‑Cheat Sheet (राउंड 1‑12)**
# 1️⃣ Full‑buy → 2️⃣ Eco → 3️⃣ Full‑buy → 4️⃣ Force‑buy → 5️⃣ Eco → 6️⃣ Full‑buy → …
#
# ---
#
# ## 6️⃣ VOD Review & Self‑Analysis
#
# 1. **हर 2‑3 गेम** का 5‑minute क्लिप बनाओ।
# 2. **3‑पॉइंट फ़ोकस** –
#    - **Aim** (क्या आप हेडशॉट ले रहे थे?)
#    - **Position** (क्या आप “over‑exposed” थे?)
#    - **Decision** (क्या आप सही टाइम पर “push” या “rotate” किया?)
# 3. **एक‑दो चीज़** नोट करो और अगले गेम में सुधार करो।
# 4. **Pro‑player VOD** (Sage, Jett, etc.) देखें और “what they did differently” लिखें।
#
# ---
#
# ## 7️⃣ Mental & Physical Health
#
# | क्या करना है | क्यों? |
# |--------------|-------|
# | **5‑minute break** हर 1‑hour गेम के बाद | “टिल्ट” कम होगा, फोकस बना रहेगा |
# | **स्ट्रीच/हैंड‑exercises** (कलाई, कंधा) | “रैपिड‑aim” के लिए मसल्स रिलैक्स |
# | **Sleep** – कम से कम 7 घंटे | “Reaction time” सुधरेगा |
# | **Positive self‑talk** – “I’m improving, not stuck” | “टिल्ट” को दूर रखेगा |
#
# ---
#
# ## 📅 Weekly “Climb‑Plan” (उदाहरण)
#
# | दिन | एक्टिविटी | टाइम |
# |-----|-----------|------|
# | **Mon** | Aim‑Lab + Warm‑up | 30 min |
# | **Tue** | Map‑walkthrough (Bind) + VOD review | 45 min |
# | **Wed** | 2‑hour Ranked (focus: communication) | 2 hr |
# | **Thu** | Agent‑specific drills (Sage wall) | 30 min |
# | **Fri** | Flex‑games (try new agent) + Review | 1 hr |
# | **Sat** | 2‑hour Ranked (apply all) + post‑game notes | 2 hr |
# | **Sun** | Rest / Light gaming / Stretch | – |
#
# ---
#
# ## 🎯 TL;DR – 5‑Step “Silver‑to‑Gold” Checklist
#
# 1. **Aim** – 20 min daily Aim‑Lab + 5 min range “head‑only”.
# 2. **Map** – हर मैप के 3‑4 “core angles” को याद करो, हर राउंड में “crosshair‑placement”.
# 3. **Comm** – हर कॉल 2‑3 सेकंड में दो, पॉज़िटिव रहें।
# 4. **Agent** – 2‑3 एजेंट को “master” करो, उनका utility 100% इस्तेमाल करो।
# 5. **Review** – हर 2‑3 गेम में 5‑minute VOD, 3‑point सुधार नोट करो।
#
# ---
#
# **अंत में एक छोटा सा मंत्र:**
# > “**Practice** करो, **Analyze** करो, **Communicate** करो, और **Enjoy** करो।”
#
# अगर आप इस प्लान को लगातार 2‑3 हफ़्तों तक फॉलो करेंगे, तो “Silver” से “Gold” की ओर आपका रैंक ग्रेडियेंट ज़रूर दिखेगा। अगर कभी फँस जाओ, तो बस VOD फिर से देखो और “what‑I‑could‑have‑done‑better” पर फोकस करो।
#
# **Good luck, भाई!** 🎮💪
# *अगर और कोई ख़ास सवाल है – एजेंट‑स्पेसिफिक या मैप‑टैक्टिक – बेझिझक पूछो!*
