# %%
from langchain_groq import ChatGroq
from dotenv import load_dotenv
load_dotenv()
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate

# %%
out = StrOutputParser()

# %%
llm = ChatGroq(model="openai/gpt-oss-120b", streaming=True)

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a translator that translates text to casual {language}."),
    ("human", "{query}")
])

# %%
chains = prompt | llm | out

# %%
res = chains.invoke({"language":"Hinglish", "query":"I love LangChain"})
res
# Out:
# 'Mujhe\u202fLangChain\u202fbohot\u202fpasand\u202fhai.'
